# %% [markdown]
# # Creating plots of your dataframes

# %% [markdown]
# ### The easiest way to create plots good plot is these 2 options:
# #### - use the seaborn library for plots
# #### - or if you want interactive plots use a library called plotly express

# %%
import pandas as pd
import seaborn as sns

import plotly.express as px

# some nicer plotly setting
import plotly.io as pio
pio.templates.default = 'plotly_white'

df = pd.read_csv('https://github.com/wortell-smart-learning/python-data-fundamentals/raw/main/data/most_voted_titles_enriched.csv')

df.head(3)
# Out:
#       tconst titleType                 primaryTitle  \
# 0  tt0010323     movie  The Cabinet of Dr. Caligari
# 1  tt0012349     movie                      The Kid
# 2  tt0013442     movie                    Nosferatu
#
#                            originalTitle  isAdult  startYear  endYear  \
# 0           Das Cabinet des Dr. Caligari        0       1920      NaN
# 1                                The Kid        0       1921      NaN
# 2  Nosferatu, eine Symphonie des Grauens        0       1922      NaN
#
#    runtimeMinutes                  genres   genre1  ...  country  \
# 0            76.0  Fantasy,Horror,Mystery  Fantasy  ...  Germany
# 1            68.0     Comedy,Drama,Family   Comedy  ...      USA
# 2            94.0          Fantasy,Horror  Fantasy  ...  Germany
#
#   primary_language            color    budget  opening_weekend_usa  gross_usa  \
# 0              NaN  Black and White   $18,000                  NaN     $8,811
# 1              NaN  Black and White  $250,000                  NaN        NaN
# 2              NaN  Black and White       NaN                  NaN        NaN
#
#   cumulative_worldwide                                            tagline  \
# 0               $8,811                          You must become Caligari.
# 1              $26,916  This is the great film he has been working on ...
# 2              $19,054  A thrilling mystery masterpiece - a chilling p...
#
#                                              summary  \
# 0  Hypnotist Dr. Caligari uses a somnambulist, Ce...
# 1  The Tramp cares for an abandoned child, but ev...
# 2  Vampire Count Orlok expresses interest in a ne...
#
#                                            image_url
# 0  https://m.media-amazon.com/images/M/MV5BNWJiNG...
# 1  https://m.media-amazon.com/images/M/MV5BZjhhMT...
# 2  https://m.media-amazon.com/images/M/MV5BMTAxYj...
#
# [3 rows x 26 columns]

# %% [markdown]
# ### Let's see how you make a scatter plot in seaborn and plot runtime vs the average rating.
# ### The syntax is usually like this:
# #### - specify the dataframe you want to use
# #### - specify your x-variable
# #### - specify your y-variable
# #### - and if you would like to color certain points, then specify the hue

# %% [markdown]
# ### Here's the seaborn way of doing things.<br>Let's show a scatter plot of `runtimeMinutes` on the x-axis and `averageRating` on the y-axis and let's color by `titleType`

# %%
sns.scatterplot(
    data=df,
    x='runtimeMinutes',
    y='averageRating',
    hue='titleType',
    s=3.
)
# Out:
# <Axes: xlabel='runtimeMinutes', ylabel='averageRating'>

# %% [markdown]
# ### But plotting interactive plots is just as easy and makes it easier to check outliers. We are using plotly.express for this.

# %%
px.scatter(
    title='runtime vs average rating',
    data_frame=df.query('runtimeMinutes <400'),
    x='runtimeMinutes',
    y='averageRating',
    color='titleType',
    hover_data=['primaryTitle'],
    opacity=0.4,
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="aecaa938-d008-4cc8-86ae-5478c97eeb55" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aecaa938-d008-4cc8-86ae-5478c97eeb55")) {                    Plotly.newPlot(                        "aecaa938-d008-4cc8-86ae-5478c97eeb55",                        [{"customdata":[["The Cabinet of Dr. Caligari"],["The Kid"],["Nosferatu"],["Sherlock Jr."],["Battleship Potemkin"],["The Gold Rush"],["Metropolis"],["The General"],["Sunrise"],["The Circus"],["The Passion of Joan of Arc"],["All Quiet on the Western Front"],["City Lights"],["Dracula"],["Frankenstein"],["M"],["Freaks"],["Scarface"],["Duck Soup"],["The Invisible Man"],["King Kong"],["It Happened One Night"],["The Thin Man"],["The 39 Steps"],["The Bride of Frankenstein"],["A Night at the Opera"],["Modern Times"],["The Grand Illusion"],["Snow White and the Seven Dwarfs"],["The Adventures of Robin Hood"],["Bringing Up Baby"],["The Lady Vanishes"],["Gone with the Wind"],["Mr. Smith Goes to Washington"],["The Rules of the Game"],["Stagecoach"],["The Wizard of Oz"],["Fantasia"],["The Grapes of Wrath"],["The Great Dictator"],["His Girl Friday"],["The Philadelphia Story"],["Pinocchio"],["Rebecca"],["The Shop Around the Corner"],["Citizen Kane"],["Dumbo"],["The Maltese Falcon"],["Suspicion"],["Bambi"],["Casablanca"],["Kate & Leopold"],["To Be or Not to Be"],["Shadow of a Doubt"],["Arsenic and Old Lace"],["Double Indemnity"],["The Best Years of Our Lives"],["Laura"],["Lifeboat"],["To Have and Have Not"],["Brief Encounter"],["The Lost Weekend"],["Spellbound"],["The Big Sleep"],["Gilda"],["It's a Wonderful Life"],["Notorious"],["Miracle on 34th Street"],["Out of the Past"],["Key Largo"],["Bicycle Thieves"],["The Lady from Shanghai"],["Red River"],["The Red Shoes"],["Rope"],["The Treasure of the Sierra Madre"],["Kind Hearts and Coronets"],["The Third Man"],["White Heat"],["All About Eve"],["Cinderella"],["Harvey"],["In a Lonely Place"],["Rashomon"],["Sunset Blvd."],["The African Queen"],["Alice in Wonderland"],["An American in Paris"],["Ace in the Hole"],["The Day the Earth Stood Still"],["Strangers on a Train"],["A Streetcar Named Desire"],["The Thing from Another World"],["High Noon"],["Ikiru"],["The Quiet Man"],["Singin' in the Rain"],["From Here to Eternity"],["Gentlemen Prefer Blondes"],["Peter Pan"],["Roman Holiday"],["The Wages of Fear"],["Shane"],["Stalag 17"],["Tokyo Story"],["The War of the Worlds"],["20,000 Leagues Under the Sea"],["Creature from the Black Lagoon"],["Diabolique"],["Dial M for Murder"],["Godzilla"],["On the Waterfront"],["Rear Window"],["Sabrina"],["Seven Samurai"],["La Strada"],["White Christmas"],["Rififi"],["East of Eden"],["Lady and the Tramp"],["The Ladykillers"],["The Night of the Hunter"],["Rebel Without a Cause"],["The Seven Year Itch"],["To Catch a Thief"],["The Trouble with Harry"],["Forbidden Planet"],["Giant"],["Invasion of the Body Snatchers"],["The Killing"],["The Man Who Knew Too Much"],["The Searchers"],["The Ten Commandments"],["12 Angry Men"],["An Affair to Remember"],["The Bridge on the River Kwai"],["Funny Face"],["Throne of Blood"],["Nights of Cabiria"],["Paths of Glory"],["The Seventh Seal"],["Wild Strawberries"],["Sweet Smell of Success"],["Witness for the Prosecution"],["The Wrong Man"],["Cat on a Hot Tin Roof"],["The Hidden Fortress"],["Plan 9 from Outer Space"],["Touch of Evil"],["Vertigo"],["Anatomy of a Murder"],["Ben-Hur"],["Hiroshima Mon Amour"],["North by Northwest"],["The 400 Blows"],["Rio Bravo"],["Sleeping Beauty"],["Some Like It Hot"],["Eyes Without a Face"],["Breathless"],["The Apartment"],["L'Avventura"],["La Dolce Vita"],["Inherit the Wind"],["The Virgin Spring"],["The Magnificent Seven"],["Peeping Tom"],["Psycho"],["Spartacus ...

# %% [markdown]
# ### There all sorts of plots with plotly.express. Here's an example of a histogram of averageRating

# %%
px.histogram(
    title='Histogram of average rating vs titletype',
    data_frame=df,
    x='averageRating',
    color='titleType',
    histnorm='probability density',
    opacity=0.3
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="90ac572a-b9cd-4031-834f-1e408e505459" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("90ac572a-b9cd-4031-834f-1e408e505459")) {                    Plotly.newPlot(                        "90ac572a-b9cd-4031-834f-1e408e505459",                        [{"alignmentgroup":"True","bingroup":"x","histnorm":"probability density","hovertemplate":"titleType=movie\u003cbr\u003eaverageRating=%{x}\u003cbr\u003eprobability density=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"movie","marker":{"color":"#636efa","opacity":0.3,"pattern":{"shape":""}},"name":"movie","offsetgroup":"movie","orientation":"v","showlegend":true,"x":[8.1,8.3,7.9,8.2,8.0,8.2,8.3,8.1,8.1,8.1,8.1,8.0,8.5,7.5,7.8,8.3,7.9,7.8,7.8,7.7,7.9,8.1,8.0,7.6,7.8,7.9,8.5,8.1,7.6,7.9,7.9,7.8,8.1,8.1,8.0,7.8,8.0,7.7,8.0,8.4,7.9,7.9,7.4,8.1,8.1,8.3,7.2,8.0,7.4,7.3,8.5,6.4,8.2,7.8,8.0,8.3,8.0,8.0,7.6,7.8,8.0,7.9,7.6,7.9,7.7,8.6,7.9,7.9,8.0,7.8,8.3,7.6,7.8,8.1,8.0,8.2,8.0,8.1,8.1,8.2,7.3,7.9,8.0,8.2,8.4,7.7,7.4,7.2,8.1,7.7,7.9,8.0,7.1,7.9,8.3,7.7,8.3,7.6,7.2,7.3,8.0,8.1,7.6,8.0,8.2,7.1,7.2,7.0,8.0,8.2,7.6,8.1,8.4,7.7,8.6,8.0,7.6,8.2,7.9,7.3,7.7,8.0,7.7,7.1,7.4,7.1,7.6,7.6,7.7,8.0,7.4,7.9,7.9,9.0,7.5,8.1,7.0,8.1,8.1,8.4,8.2,8.2,8.0,8.4,7.4,8.0,8.1,4.0,8.0,8.3,8.0,8.1,7.9,8.3,8.1,8.0,7.2,8.2,7.7,7.8,8.3,7.9,8.0,8.1,8.1,7.7,7.7,8.5,7.9,7.6,7.6,7.5,8.0,7.8,8.2,7.8,7.3,7.5,8.2,7.7,7.2,8.6,8.1,8.3,7.6,7.8,8.1,7.9,8.1,8.2,8.0,8.1,8.1,8.0,7.7,7.9,7.0,8.4,7.4,8.2,7.5,7.5,7.6,7.1,7.2,8.4,7.7,7.6,7.2,7.8,7.8,8.0,7.5,7.7,8.1,8.0,8.3,7.6,7.7,8.0,7.0,8.1,6.5,7.6,8.8,7.2,7.7,1.9,8.1,8.0,7.7,7.8,5.1,8.1,7.7,7.2,8.0,7.8,7.0,7.9,7.6,8.1,7.8,6.9,8.3,5.9,7.4,6.9,7.9,7.9,7.7,7.4,7.5,8.0,7.6,7.6,8.0,8.0,8.5,7.3,7.3,7.8,6.7,7.3,7.4,7.7,7.9,7.1,6.1,8.0,7.5,7.6,7.6,6.9,7.4,7.9,6.7,7.5,8.4,7.6,7.2,7.0,7.1,8.3,6.6,7.7,6.3,8.0,7.7,7.4,7.6,7.9,8.0,6.5,7.0,6.7,7.5,7.4,7.2,7.8,7.9,7.8,7.9,6.1,7.7,6.8,7.4,7.4,9.2,7.5,7.6,7.4,6.0,7.3,7.1,8.0,8.1,8.1,7.4,7.8,5.6,7.8,7.2,7.7,8.0,7.4,6.8,7.6,7.2,7.2,8.1,8.0,7.6,7.7,7.2,7.1,8.3,7.0,7.0,7.5,7.9,7.2,7.7,8.1,7.8,7.0,9.0,7.9,6.8,8.2,7.3,7.1,7.7,7.5,7.0,8.0,8.1,8.1,8.0,8.0,7.7,7.8,8.7,7.5,7.6,7.4,5.9,8.2,7.4,8.0,7.4,7.4,6.8,7.4,7.5,5.9,7.7,6.8,7.4,8.2,7.4,8.1,7.5,7.8,7.2,8.1,8.3,8.0,7.4,7.6,7.6,6.9,6.8,7.3,7.0,7.1,8.6,7.4,7.0,6.3,7.9,7.8,7.3,8.1,7.2,7.7,6.3,8.2,5.7,7.4,5.8,6.2,7.6,7.5,7.3,7.0,7.6,7.4,5.8,8.4,7.9,6.3,8.4,8.0,6.9,5.9,7.4,7.6,7.6,7.2,7.8,8.1,6.9,7.9,6.3,7.6,7.5,6.7,7.3,7.7,8.2,6.4,6.9,7.6,7.5,6.9,7.7,6.9,5.8,7.9,7.3,5.4,7.2,7.1,8.1,8.7,6.5,6.8,6.5,7.3,8.0,7.7,5.3,8.2,6.8,8.4,7.2,6.8,6.8,7.0,7.5,6.9,7.4,7.4,8.3,6.3,7.2,6.9,6.9,7.2,7.4,6.7,7.3,6.1,7.4,6.5,6.7,6.9,6.6,7.6,7.6,6.6,7.4,8.4,6.9,7.4,6.7,6.9,6.2,6.6,8.1,6.9,7.2,7.8,7.5,8.1,7.2,6.0,7.7,8.1,5.7,8.0,4.4,7.0,8.1,7.3,6.2,6.8,7.6,7.6,7.7,8.1,7.4,6.8,7.7,7.2,6.7,7.9,6.1,7.2,6.2,5.0,3.7,7.8,8.3,6.1,7.5,7.4,6.2,6.6,7.1,8.3,7.8,6.8,7.2,8.3,6.3,6.7,5.0,7.4,7.5,6.5,7.2,7.1,7.7,6.8,8.3,6.3,7.3,7.6,6.8,5.7,5.9,6.5,6.1,6.6,6.0,7.8,7.3,7.6,7.3,8.1,7.8,6.8,7.5,7.5,7.1,8.4,8.1,6.7,6.4,6.9,6.7,6.9,7.1,6.3,6.7,7.0,7.5,8.0,7.9,7.2,7.4,7.7,8.5,7.1,6.4,7.9,7.8,6.6,7.3,6.7,7.8,6.7,7.2,6.9,6.9,4.8,7.1,7.8,6.2,7.6,7.0,6.5,6.3,7.2,6.2,5.5,7.2,7.3,7.0,5.8,7.7,6.5,8.2,7.2,7.0,5.1,7.3,6.9,7.2,7.2,6.5,6.4,6.1,7.3,6.3,6.4,6.6,7.4,6.6,8.3,6.9,6.7,7.3,7.7,5.8,7.0,6.1,7.8,7.8,6.9,7.6,6.0,6.0,7.2,7.9,6.9,7.1,7.2,7.5,4.7,8.3,6.1,7.4,7.0,7.2,5.5,7.4,6.4,6.6,7.7,6.0,6.3,8.1,5.4,6.8,5.6,7.3,6.9,6.7,7.0,8.1,7.3,8.0,5.6,6.5,6.9,7.3,5.7,6.7,6.9,7.3,8.0,6.6,6.5,6.8,7.2,6.8,7.0,6.0,7.7,7.8,6.9,8.3,7.3,6.0,7.0,8.0,6.8,3.0,6.9,7.7,7.6,6.7,7.3,6.0,5.4,7.1,7.1,7.0,6.6,7.1,5.8,6.9,7.6,5.0,7.8,6.7,8.0,7.5,7.3,7.5,6.6,6.7,6.5,7.1,7.1,3.7,6.1,6.3,7.9,7.4,6.6,7.7,6.0,7.1,8.0,7.5,7.3,6.5,7.1,6.6,5.9,7.0,7.6,6.3,7.3,8.2,7.4,7.5,6.9,5.3,7 ...

# %% [markdown]
# ### Or a boxplot of rating by titletype

# %%
px.box(
    title='Comparing average rating by titleType',
    data_frame=df,
    x='titleType',
    y='averageRating',
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="67141410-7c1a-45c1-a0ad-056cdae2d834" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("67141410-7c1a-45c1-a0ad-056cdae2d834")) {                    Plotly.newPlot(                        "67141410-7c1a-45c1-a0ad-056cdae2d834",                        [{"alignmentgroup":"True","hovertemplate":"titleType=%{x}\u003cbr\u003eaverageRating=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","tvSeries","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","tvSeries","tvSeries","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","tvSeries","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","tvSeries","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","tvSeries","tvSeries","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","tvSeries","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","tvSeries","tvSeries","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie","movie"," ...

# %% [markdown]
# ### Sometimes you don't even need to specify the x and y value. This is the case when there's only an index and 1 column

# %%
px.bar(df['country'].value_counts().head(5))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="223917b9-7d4e-44f1-8a2e-f93773e8578e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("223917b9-7d4e-44f1-8a2e-f93773e8578e")) {                    Plotly.newPlot(                        "223917b9-7d4e-44f1-8a2e-f93773e8578e",                        [{"alignmentgroup":"True","hovertemplate":"variable=count\u003cbr\u003ecountry=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"count","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"count","offsetgroup":"count","orientation":"v","showlegend":true,"textposition":"auto","x":["USA","UK","France","Canada","India"],"xaxis":"x","y":[4066,621,180,130,118],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo ...
