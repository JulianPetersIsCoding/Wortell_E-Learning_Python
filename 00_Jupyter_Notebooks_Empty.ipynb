# %% [markdown]
# # Jupyter notebooks + quick Python refresher

# %% [markdown]
# ---

# %% [markdown]
# ### Why use Jupyter Notebooks? They make it very handy to:
# - Try out code and experiment with it
# - Combine code with plots of your data
# - Annotate your code and findings with markdown, just like this text.
# - You don't need to rerun your script every time, but can choose parts of it: variables are kept in memory

# %% [markdown]
# ---

# %% [markdown]
# ### You can run code in Jupyter Notebook by using the shortcut <kbd>Shift</kbd> + <kbd>Enter</kbd> inside the code cell.<br>Let's write a welcome text assign it to a variable and use `print()` to get the output

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# ### But Jupyter notebook doesn't need the `print()` statement to print a variable. It will print the string representation of your variable when you just type it and then execute it with `Shift + Enter`. See what happens when you just run the code below:

# %%
Welkomtekst = "Hello World"
print(Welkomtekst)
# Out:
# Hello World

# %% [markdown]
# ---

# %% [markdown]
# ### What is also very handy, is the `Shift + Tab` inside functions: it shows you all the arguments of that function. See what happens for yourself if you use `Shift + Tab` inside the `print()` function below:

# %%
print()

# %% [markdown]
# ### You can also get information about the documentation of the function, by putting a question mark `?` in front of it and running the cell.

# %%
# ?print

# %% [markdown]
# ---

# %% [markdown]
# ### Good to know is that you also run simple command line statements and other with so-called **magic commands**. They have a `%` in front of the statement. Below is an example with `ls`. This is not a python statement but it will run nevertheless. Please run it and see what happens:

# %%
# %ls sample_data/
# Out:
# anscombe.json*                mnist_test.csv
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  README.md*

# %% [markdown]
# # Dit is nu een markdown
# print("Hallo")

# %% [markdown]
# ### Converting your cell from code to markdown can be done by pressing `Escape` followed by `m`:

# %% [markdown]
# #### Just writing some markdown
# - bullet 1
# - bullet 2

# %% [markdown]
# ### Let's try writing some markdown:

# %% [markdown]
# # Heading 1
#
# ## Heading 2
#
# * bullet 1
# * bullet 2
#
# 1. numerieke
# 1. lijst
#
# 12. Nu hier
# 12. Doortellen
#
# [Google](https://www.google.com)
#
# ![Wortell_Logo](https://www.wortell.nl/favicon.ico)

# %% [markdown]
# ---

# %% [markdown]
# ### You can create new code cells by pressing `Escape` followed by `a` (a stands for above). This is very much like a vim code editor. Please try to add some new code cells.

# %% [markdown]
# ### The same goes for adding a new code cell below. This can be done by `Escape` followed by `b` (b stands for below)

# %% [markdown]
# ### Deleting cells can be done with `Escape` followed by `dd`. Please delete the cells you just added above or below:

# %%
for i in range(5):
  print(f"Dit is een stuk Python-cde dat voor de {i+1}e keer wordt weergegeven")
# Out:
# Dit is een stuk Python-cde dat voor de 1e keer wordt weergegeven
# Dit is een stuk Python-cde dat voor de 2e keer wordt weergegeven
# Dit is een stuk Python-cde dat voor de 3e keer wordt weergegeven
# Dit is een stuk Python-cde dat voor de 4e keer wordt weergegeven
# Dit is een stuk Python-cde dat voor de 5e keer wordt weergegeven

# %% [markdown]
# ---

# %% [markdown]
# ### Python has list over which you can easily iterate. Notice the 4 space indentation (or 1 tab).<br>Let's write a fruit list `['apples', 'banana', 2, 'oranges']` and loop over it.

# %%
my_fruits_list = ['apples', 'Banana', 2, 'oranges']

# %%
for vrucht in my_fruits_list:
  print("Ik ga deze vrucht kopen", vrucht)

print("Deze voer ik 1 keer uit")
# Out:
# Ik ga deze vrucht kopen apples
# Ik ga deze vrucht kopen Banana
# Ik ga deze vrucht kopen 2
# Ik ga deze vrucht kopen oranges
# Deze voer ik 1 keer uit

# %% [markdown]
# ### This is very different from other programming languages where you might write something like this. Here you can also see python's focus on ease and readability:

# %%
for i in range(0, len(my_fruits_list)):
    print(my_fruits_list[i])
# Out:
# apples
# Banana
# 2
# oranges

# %% [markdown]
# ### Or even something like this:

# %%
i = 0

while i < len(my_fruits_list):
    print(my_fruits_list[i])
    i += 1
# Out:
# apples
# Banana
# 2
# oranges

# %% [markdown]
# ### Slicing lists using brackets. Slicing starts at 0

# %%
my_fruits_list[0]
# Out:
# 'apples'

# %% [markdown]
# ### Getting the last element of a list

# %%
modules = [ "Introductie Notebooks en Python", "Werken met Dataframes in Pandas", "Data Wrangling in Python" ]

for module in modules:
  print(module)
# Out:
# Introductie Notebooks en Python
# Werken met Dataframes in Pandas
# Data Wrangling in Python

# %% [markdown]
# ---

# %% [markdown]
# ### Python dictionary: key value pairs, unordered.

# %%
boodschappendictionairy = {
    'appels': {"Granny Smith": 10,
               "Elstar": 5},
    'peren': 3,
    'thee' : "100g"
}

boodschappendictionairy["appels"]
# Out:
# {'Granny Smith': 10, 'Elstar': 5}

# %% [markdown]
# ---

# %% [markdown]
# ### Defining a function with `def`:

# %%
def add_two_numbers(getal1, getal2):
  return getal1 + getal2

# %%
add_two_numbers(1,2)
# Out:
# 3
