# %% [markdown]
# # Creating selections and subsets of your data

# %% [markdown]
# ### There are many ways to get selections or subsets of your data:
# #### - selecting a column with `df['averageRating']`
# #### - selecting multiple columns using a list: `df[['tconst', 'averageRating']]`
# #### - selecting a subset using a condition: `df[df['averageRating'] > 9.0]`
# #### - using `.query("averageRating > 0")`

# %% [markdown]
# ### Let's first read in our data again and check the first few lines

# %%
import pandas as pd
pd.options.display.max_columns = 50

df = pd.read_csv('https://github.com/wortell-smart-learning/python-data-fundamentals/raw/main/data/most_voted_titles_enriched.csv')

df.head(3)
# Out:
#       tconst titleType                 primaryTitle  \
# 0  tt0010323     movie  The Cabinet of Dr. Caligari
# 1  tt0012349     movie                      The Kid
# 2  tt0013442     movie                    Nosferatu
#
#                            originalTitle  isAdult  startYear  endYear  \
# 0           Das Cabinet des Dr. Caligari        0       1920      NaN
# 1                                The Kid        0       1921      NaN
# 2  Nosferatu, eine Symphonie des Grauens        0       1922      NaN
#
#    runtimeMinutes                  genres   genre1  genre2   genre3  \
# 0            76.0  Fantasy,Horror,Mystery  Fantasy  Horror  Mystery
# 1            68.0     Comedy,Drama,Family   Comedy   Drama   Family
# 2            94.0          Fantasy,Horror  Fantasy  Horror      NaN
#
#                                     url  averageRating  numVotes  metascore  \
# 0  https://www.imdb.com/title/tt0010323            8.1     57097        NaN
# 1  https://www.imdb.com/title/tt0012349            8.3    112377        NaN
# 2  https://www.imdb.com/title/tt0013442            7.9     88440        NaN
#
#    country primary_language            color    budget opening_weekend_usa  \
# 0  Germany              NaN  Black and White   $18,000                 NaN
# 1      USA              NaN  Black and White  $250,000                 NaN
# 2  Germany              NaN  Black and White       NaN                 NaN
#
#   gross_usa cumulative_worldwide  \
# 0    $8,811               $8,811
# 1       NaN              $26,916
# 2       NaN              $19,054
#
#                                              tagline  \
# 0                          You must become Caligari.
# 1  This is the great film he has been working on ...
# 2  A thrilling mystery masterpiece - a chilling p...
#
#                                              summary  \
# 0  Hypnotist Dr. Caligari uses a somnambulist, Ce...
# 1  The Tramp cares for an abandoned child, but ev...
# 2  Vampire Count Orlok expresses interest in a ne...
#
#                                            image_url
# 0  https://m.media-amazon.com/images/M/MV5BNWJiNG...
# 1  https://m.media-amazon.com/images/M/MV5BZjhhMT...
# 2  https://m.media-amazon.com/images/M/MV5BMTAxYj...

# %% [markdown]
# ## Let's say we only want 1 column. How do we do that? Here are 2 ways:

# %% [markdown]
# ### 1. Specifying the column you want: let's say we want to only look at the startYear column

# %%
df['startYear']
# Out:
# 0       1920
# 1       1921
# 2       1922
# 3       1924
# 4       1925
#         ...
# 5825    2020
# 5826    2020
# 5827    2020
# 5828    2019
# 5829    2020
# Name: startYear, Length: 5830, dtype: int64

# %% [markdown]
# ### Specifying only 1 column gives you a Series

# %%
type(df['startYear'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### 2. The column names are also attributes, so you also use the dot notation

# %%
df.startYear
# Out:
# 0       1920
# 1       1921
# 2       1922
# 3       1924
# 4       1925
#         ...
# 5825    2020
# 5826    2020
# 5827    2020
# 5828    2019
# 5829    2020
# Name: startYear, Length: 5830, dtype: int64

# %% [markdown]
# ### So selecting multiple columns can be done by using a list

# %%
columns_needed = ['tconst', 'averageRating', 'startYear']

df[columns_needed]
# Out:
#          tconst  averageRating  startYear
# 0     tt0010323            8.1       1920
# 1     tt0012349            8.3       1921
# 2     tt0013442            7.9       1922
# 3     tt0015324            8.2       1924
# 4     tt0015648            8.0       1925
# ...         ...            ...        ...
# 5825  tt9686708            7.1       2020
# 5826  tt9698480            7.3       2020
# 5827  tt9777644            6.5       2020
# 5828  tt9806192            7.6       2019
# 5829  tt9866072            6.1       2020
#
# [5830 rows x 3 columns]

# %% [markdown]
# ### Let's say you only want titles with an average rating greater than 9.0. We need to use boolean vectors:

# %%
df['averageRating'] > 9.0
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5825    False
# 5826    False
# 5827    False
# 5828    False
# 5829    False
# Name: averageRating, Length: 5830, dtype: bool

# %%
df[df['averageRating'] > 9.0].head(3)
# Out:
#          tconst titleType              primaryTitle             originalTitle  \
# 316   tt0068646     movie             The Godfather             The Godfather
# 1214  tt0111161     movie  The Shawshank Redemption  The Shawshank Redemption
# 1712  tt0141842  tvSeries              The Sopranos              The Sopranos
#
#       isAdult  startYear  endYear  runtimeMinutes       genres genre1 genre2  \
# 316         0       1972      NaN           175.0  Crime,Drama  Crime  Drama
# 1214        0       1994      NaN           142.0        Drama  Drama    NaN
# 1712        0       1999   2007.0            55.0  Crime,Drama  Crime  Drama
#
#      genre3                                   url  averageRating  numVotes  \
# 316     NaN  https://www.imdb.com/title/tt0068646            9.2   1608367
# 1214    NaN  https://www.imdb.com/title/tt0111161            9.3   2327795
# 1712    NaN  https://www.imdb.com/title/tt0141842            9.2    297011
#
#       metascore country primary_language  color       budget  \
# 316       100.0     USA          English  Color   $6,000,000
# 1214       80.0     USA          English  Color  $25,000,000
# 1712        NaN     USA          English  Color          NaN
#
#      opening_weekend_usa     gross_usa cumulative_worldwide  \
# 316            $302,393,  $134,966,411         $246,120,986
# 1214           $727,327,   $28,699,976          $28,817,291
# 1712                 NaN           NaN                  NaN
#
#                                                 tagline  \
# 316                          An offer you can't refuse.
# 1214  Fear can hold you prisoner. Hope can set you f...
# 1712      Hell hath no fury like The Family. (season 5)
#
#                                                 summary  \
# 316   The aging patriarch of an organized crime dyna...
# 1214  Two imprisoned men bond over a number of years...
# 1712  New Jersey mob boss Tony Soprano deals with pe...
#
#                                               image_url
# 316   https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 1214  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1712  https://m.media-amazon.com/images/M/MV5BZGJjYz...

# %% [markdown]
# ### But we want multiple conditions: average rating greater than 9 AND only movies:

# %%
(df['titleType'] == 'movie')
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 5825     True
# 5826    False
# 5827     True
# 5828     True
# 5829     True
# Name: titleType, Length: 5830, dtype: bool

# %%
(df['averageRating'] > 9.0)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5825    False
# 5826    False
# 5827    False
# 5828    False
# 5829    False
# Name: averageRating, Length: 5830, dtype: bool

# %%
df[(df['titleType'] == 'movie') & (df['averageRating'] > 9.0)].head(2)
# Out:
#          tconst titleType              primaryTitle             originalTitle  \
# 316   tt0068646     movie             The Godfather             The Godfather
# 1214  tt0111161     movie  The Shawshank Redemption  The Shawshank Redemption
#
#       isAdult  startYear  endYear  runtimeMinutes       genres genre1 genre2  \
# 316         0       1972      NaN           175.0  Crime,Drama  Crime  Drama
# 1214        0       1994      NaN           142.0        Drama  Drama    NaN
#
#      genre3                                   url  averageRating  numVotes  \
# 316     NaN  https://www.imdb.com/title/tt0068646            9.2   1608367
# 1214    NaN  https://www.imdb.com/title/tt0111161            9.3   2327795
#
#       metascore country primary_language  color       budget  \
# 316       100.0     USA          English  Color   $6,000,000
# 1214       80.0     USA          English  Color  $25,000,000
#
#      opening_weekend_usa     gross_usa cumulative_worldwide  \
# 316            $302,393,  $134,966,411         $246,120,986
# 1214           $727,327,   $28,699,976          $28,817,291
#
#                                                 tagline  \
# 316                          An offer you can't refuse.
# 1214  Fear can hold you prisoner. Hope can set you f...
#
#                                                 summary  \
# 316   The aging patriarch of an organized crime dyna...
# 1214  Two imprisoned men bond over a number of years...
#
#                                               image_url
# 316   https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 1214  https://m.media-amazon.com/images/M/MV5BMDFkYT...

# %% [markdown]
# ### But this gets tedious, so I myself prefer to use the dataframe method `.query()`

# %%
df.query("titleType == 'movie' and averageRating > 9").head(2)
# Out:
#          tconst titleType              primaryTitle             originalTitle  \
# 316   tt0068646     movie             The Godfather             The Godfather
# 1214  tt0111161     movie  The Shawshank Redemption  The Shawshank Redemption
#
#       isAdult  startYear  endYear  runtimeMinutes       genres genre1 genre2  \
# 316         0       1972      NaN           175.0  Crime,Drama  Crime  Drama
# 1214        0       1994      NaN           142.0        Drama  Drama    NaN
#
#      genre3                                   url  averageRating  numVotes  \
# 316     NaN  https://www.imdb.com/title/tt0068646            9.2   1608367
# 1214    NaN  https://www.imdb.com/title/tt0111161            9.3   2327795
#
#       metascore country primary_language  color       budget  \
# 316       100.0     USA          English  Color   $6,000,000
# 1214       80.0     USA          English  Color  $25,000,000
#
#      opening_weekend_usa     gross_usa cumulative_worldwide  \
# 316            $302,393,  $134,966,411         $246,120,986
# 1214           $727,327,   $28,699,976          $28,817,291
#
#                                                 tagline  \
# 316                          An offer you can't refuse.
# 1214  Fear can hold you prisoner. Hope can set you f...
#
#                                                 summary  \
# 316   The aging patriarch of an organized crime dyna...
# 1214  Two imprisoned men bond over a number of years...
#
#                                               image_url
# 316   https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 1214  https://m.media-amazon.com/images/M/MV5BMDFkYT...

# %% [markdown]
# ### One handy way of selecting strings still is using `.isin()`

# %%
df[df['genre1'].isin(['Crime', 'Drama'])].head(2)
# Out:
#       tconst titleType         primaryTitle         originalTitle  isAdult  \
# 4  tt0015648     movie  Battleship Potemkin  Bronenosets Potemkin        0
# 6  tt0017136     movie           Metropolis            Metropolis        0
#
#    startYear  endYear  runtimeMinutes                  genres genre1   genre2  \
# 4       1925      NaN          75.000  Drama,History,Thriller  Drama  History
# 6       1927      NaN         153.000            Drama,Sci-Fi  Drama   Sci-Fi
#
#      genre3                                   url  averageRating  numVotes  \
# 4  Thriller  https://www.imdb.com/title/tt0015648          8.000     52800
# 6       NaN  https://www.imdb.com/title/tt0017136          8.300    159189
#
#    metascore       country primary_language            color        budget  \
# 4     97.000  Soviet Union             None  Black and White           NaN
# 6     98.000       Germany           German  Black and White  DEM6,000,000
#
#   opening_weekend_usa   gross_usa cumulative_worldwide  \
# 4             $5,641,     $51,198              $61,389
# 6            $19,386,  $1,236,166           $1,349,711
#
#                                              tagline  \
# 4  The Sensational Russian Film which is astoundi...
# 6  The most amazing picture ever made. Pictures a...
#
#                                              summary  \
# 4  In the midst of the Russian Revolution of 1905...
# 6  In a futuristic city sharply divided between t...
#
#                                            image_url
# 4  https://m.media-amazon.com/images/M/MV5BMTEyMT...
# 6  https://m.media-amazon.com/images/M/MV5BMTg5YW...

# %% [markdown]
# ### Ok, ok, just one more thing: if you want to find a string in a text, you can use `.str.contains('your_text', case=False)`

# %%
df[df['originalTitle'].str.contains('godfather', case=False)]
# Out:
#         tconst titleType             primaryTitle            originalTitle  \
# 316  tt0068646     movie            The Godfather            The Godfather
# 354  tt0071562     movie   The Godfather: Part II   The Godfather: Part II
# 912  tt0099674     movie  The Godfather: Part III  The Godfather: Part III
#
#      isAdult  startYear  endYear  runtimeMinutes       genres genre1 genre2  \
# 316        0       1972      NaN         175.000  Crime,Drama  Crime  Drama
# 354        0       1974      NaN         202.000  Crime,Drama  Crime  Drama
# 912        0       1990      NaN         162.000  Crime,Drama  Crime  Drama
#
#     genre3                                   url  averageRating  numVotes  \
# 316    NaN  https://www.imdb.com/title/tt0068646          9.200   1608367
# 354    NaN  https://www.imdb.com/title/tt0071562          9.000   1122882
# 912    NaN  https://www.imdb.com/title/tt0099674          7.600    357561
#
#      metascore country primary_language  color       budget  \
# 316    100.000     USA          English  Color   $6,000,000
# 354     90.000     USA          English  Color  $13,000,000
# 912     60.000     USA          English  Color  $54,000,000
#
#     opening_weekend_usa     gross_usa cumulative_worldwide  \
# 316           $302,393,  $134,966,411         $246,120,986
# 354           $171,417,   $47,834,595          $48,035,783
# 912         $6,387,271,   $66,761,392         $136,766,062
#
#                                           tagline  \
# 316                    An offer you can't refuse.
# 354  All the power on earth can't change destiny.
# 912  Real power can't be given. It must be taken.
#
#                                                summary  \
# 316  The aging patriarch of an organized crime dyna...
# 354  The early life and career of Vito Corleone in ...
# 912  Follows Michael Corleone, now in his 60s, as h...
#
#                                              image_url
# 316  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 354  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 912  https://m.media-amazon.com/images/M/MV5BNWFlYW...
