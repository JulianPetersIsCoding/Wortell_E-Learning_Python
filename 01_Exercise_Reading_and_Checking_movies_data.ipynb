# %% [markdown]
# # Let's read in and inspect some imdb movies and tv series data
#
#
# ## If you don't remember what command to use: check the cheat sheet! :)
#
#
# ## The dataset is a subset of scraped data from IMDB https://www.imdb.com/ and includes the most voted titles. Only movies with at least 25000 votes are in this dataset.
#
# ## Let's see if we can find info on the best movies and tv series or just your favorite ones!

# %% [markdown]
# ## 1) First things first: we first need to import the pandas library. Please import `pandas as pd`.

# %%
import pandas as pd

# %% [markdown]
# ## 2) Read in data from file `https://github.com/wortell-smart-learning/python-data-fundamentals/raw/main/data/most_voted_titles_enriched.csv` and assign it to a variable `df`

# %%
df = pd.read_csv("https://github.com/wortell-smart-learning/python-data-fundamentals/raw/main/data/most_voted_titles_enriched.csv")

# %% [markdown]
# ## 3) Show the first few lines of your dataframe

# %%
df.head(5)
# Out:
#       tconst titleType                 primaryTitle  \
# 0  tt0010323     movie  The Cabinet of Dr. Caligari
# 1  tt0012349     movie                      The Kid
# 2  tt0013442     movie                    Nosferatu
# 3  tt0015324     movie                 Sherlock Jr.
# 4  tt0015648     movie          Battleship Potemkin
#
#                            originalTitle  isAdult  startYear  endYear  \
# 0           Das Cabinet des Dr. Caligari        0       1920      NaN
# 1                                The Kid        0       1921      NaN
# 2  Nosferatu, eine Symphonie des Grauens        0       1922      NaN
# 3                           Sherlock Jr.        0       1924      NaN
# 4                   Bronenosets Potemkin        0       1925      NaN
#
#    runtimeMinutes                  genres   genre1  ...       country  \
# 0            76.0  Fantasy,Horror,Mystery  Fantasy  ...       Germany
# 1            68.0     Comedy,Drama,Family   Comedy  ...           USA
# 2            94.0          Fantasy,Horror  Fantasy  ...       Germany
# 3            45.0   Action,Comedy,Romance   Action  ...           USA
# 4            75.0  Drama,History,Thriller    Drama  ...  Soviet Union
#
#   primary_language            color    budget  opening_weekend_usa  gross_usa  \
# 0              NaN  Black and White   $18,000                  NaN     $8,811
# 1              NaN  Black and White  $250,000                  NaN        NaN
# 2              NaN  Black and White       NaN                  NaN        NaN
# 3              NaN  Black and White       NaN                  NaN   $977,375
# 4              NaN  Black and White       NaN              $5,641,    $51,198
#
#   cumulative_worldwide                                            tagline  \
# 0               $8,811                          You must become Caligari.
# 1              $26,916  This is the great film he has been working on ...
# 2              $19,054  A thrilling mystery masterpiece - a chilling p...
# 3                  NaN          every inch of footage holds such a laugh!
# 4              $61,389  The Sensational Russian Film which is astoundi...
#
#                                              summary  \
# 0  Hypnotist Dr. Caligari uses a somnambulist, Ce...
# 1  The Tramp cares for an abandoned child, but ev...
# 2  Vampire Count Orlok expresses interest in a ne...
# 3  A film projectionist longs to be a detective, ...
# 4  In the midst of the Russian Revolution of 1905...
#
#                                            image_url
# 0  https://m.media-amazon.com/images/M/MV5BNWJiNG...
# 1  https://m.media-amazon.com/images/M/MV5BZjhhMT...
# 2  https://m.media-amazon.com/images/M/MV5BMTAxYj...
# 3  https://m.media-amazon.com/images/M/MV5BZWFhOG...
# 4  https://m.media-amazon.com/images/M/MV5BMTEyMT...
#
# [5 rows x 26 columns]

# %% [markdown]
# ## 4) What is the shape of your dataframe

# %%
df.shape
# Out:
# (5830, 26)

# %% [markdown]
# ## 5) Get an overview of general info of your dataframe: which columns are there, which datatypes do the columns have, how many null values etc.

# %%
df.columns
df.dtypes
# Out:
# tconst                   object
# titleType                object
# primaryTitle             object
# originalTitle            object
# isAdult                   int64
# startYear                 int64
# endYear                 float64
# runtimeMinutes          float64
# genres                   object
# genre1                   object
# genre2                   object
# genre3                   object
# url                      object
# averageRating           float64
# numVotes                  int64
# metascore               float64
# country                  object
# primary_language         object
# color                    object
# budget                   object
# opening_weekend_usa      object
# gross_usa                object
# cumulative_worldwide     object
# tagline                  object
# summary                  object
# image_url                object
# dtype: object

# %% [markdown]
# ## 6) How many null values are there in the columns of your dataframe?

# %%
df.isnull().sum()
df.isnull().sum().sum()
# Out:
# np.int64(13779)

# %% [markdown]
# ## 7) Print all the column names of your dataframe

# %%
print(df.columns)
# Out:
# Index(['tconst', 'titleType', 'primaryTitle', 'originalTitle', 'isAdult',
#        'startYear', 'endYear', 'runtimeMinutes', 'genres', 'genre1', 'genre2',
#        'genre3', 'url', 'averageRating', 'numVotes', 'metascore', 'country',
#        'primary_language', 'color', 'budget', 'opening_weekend_usa',
#        'gross_usa', 'cumulative_worldwide', 'tagline', 'summary', 'image_url'],
#       dtype='object')

# %% [markdown]
# ## 8) Use `df['genre1'].value_counts()` to figure out which genres there are.

# %%
df['genre1'].value_counts()
# Out:
# genre1
# Action         1654
# Comedy         1402
# Drama          1004
# Adventure       526
# Crime           464
# Biography       337
# Horror          254
# Animation        78
# Fantasy          28
# Documentary      27
# Mystery          25
# Thriller          6
# Family            5
# Film-Noir         5
# Sci-Fi            5
# Romance           5
# Western           4
# Musical           1
# Name: count, dtype: int64

# %% [markdown]
# ## 9) Also do a `.value_counts()` for column `endYear`. Try it once with argument `dropna=True` and once with using argument `dropna=False`

# %%
df.endYear.value_counts(dropna=True)
#df.endYear.value_counts(dropna=False)
# Out:
# endYear
# 2019.0    44
# 2020.0    36
# 2017.0    36
# 2018.0    34
# 2015.0    30
# 2014.0    29
# 2016.0    20
# 2013.0    20
# 2012.0    20
# 2010.0    16
# 2011.0    15
# 2007.0    13
# 2009.0    13
# 2003.0    12
# 2004.0    11
# 2006.0    10
# 2008.0     8
# 2005.0     7
# 2002.0     6
# 1998.0     6
# 1999.0     5
# 1992.0     4
# 1996.0     4
# 2001.0     4
# 1989.0     3
# 1993.0     3
# 2000.0     3
# 1995.0     3
# 1986.0     2
# 1990.0     2
# 1987.0     2
# 1997.0     2
# 1983.0     2
# 1966.0     1
# 1964.0     1
# 1979.0     1
# 1969.0     1
# 1974.0     1
# 1970.0     1
# 1975.0     1
# 1994.0     1
# 1991.0     1
# 2021.0     1
# Name: count, dtype: int64

# %% [markdown]
# ## 10) Try tab completion to see what functions and attributes are all available for your dataframe: write `df.` followed by `Tab`

# %%
df.
