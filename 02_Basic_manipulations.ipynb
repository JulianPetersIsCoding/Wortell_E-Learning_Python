# %% [markdown]
# # Basic manipulations of your dataframe

# %% [markdown]
# ### How can we add a column, delete a column, rename columns etc.?

# %%
import pandas as pd

# %%
df = pd.read_csv('https://github.com/wortell-smart-learning/python-data-fundamentals/raw/main/data/most_voted_titles_enriched.csv')

# %%
df.head(3)
# Out:
#       tconst titleType                 primaryTitle  \
# 0  tt0010323     movie  The Cabinet of Dr. Caligari
# 1  tt0012349     movie                      The Kid
# 2  tt0013442     movie                    Nosferatu
#
#                            originalTitle  isAdult  startYear  endYear  \
# 0           Das Cabinet des Dr. Caligari        0       1920      NaN
# 1                                The Kid        0       1921      NaN
# 2  Nosferatu, eine Symphonie des Grauens        0       1922      NaN
#
#    runtimeMinutes                  genres   genre1  ...  country  \
# 0            76.0  Fantasy,Horror,Mystery  Fantasy  ...  Germany
# 1            68.0     Comedy,Drama,Family   Comedy  ...      USA
# 2            94.0          Fantasy,Horror  Fantasy  ...  Germany
#
#   primary_language            color    budget  opening_weekend_usa  gross_usa  \
# 0              NaN  Black and White   $18,000                  NaN     $8,811
# 1              NaN  Black and White  $250,000                  NaN        NaN
# 2              NaN  Black and White       NaN                  NaN        NaN
#
#   cumulative_worldwide                                            tagline  \
# 0               $8,811                          You must become Caligari.
# 1              $26,916  This is the great film he has been working on ...
# 2              $19,054  A thrilling mystery masterpiece - a chilling p...
#
#                                              summary  \
# 0  Hypnotist Dr. Caligari uses a somnambulist, Ce...
# 1  The Tramp cares for an abandoned child, but ev...
# 2  Vampire Count Orlok expresses interest in a ne...
#
#                                            image_url
# 0  https://m.media-amazon.com/images/M/MV5BNWJiNG...
# 1  https://m.media-amazon.com/images/M/MV5BZjhhMT...
# 2  https://m.media-amazon.com/images/M/MV5BMTAxYj...
#
# [3 rows x 26 columns]

# %% [markdown]
# ### Notice that we don't see all columns when doing `df.head()` that's annoying.<br>Let's first check some of the standard settings and then change them:

# %%
pd.options.display.max_columns
# Out:
# 20

# %% [markdown]
# ### This means only 20 columns will be shown, but our dataframe has 26 columns. Let's change this setting:

# %%
pd.options.display.max_columns = 50

# %% [markdown]
# ### Let's say we don't like primary Title column, let's delete it

# %%
df.drop(columns=['primaryTitle']).head(3)
# Out:
#       tconst titleType                          originalTitle  isAdult  \
# 0  tt0010323     movie           Das Cabinet des Dr. Caligari        0
# 1  tt0012349     movie                                The Kid        0
# 2  tt0013442     movie  Nosferatu, eine Symphonie des Grauens        0
#
#    startYear  endYear  runtimeMinutes                  genres   genre1  \
# 0       1920      NaN            76.0  Fantasy,Horror,Mystery  Fantasy
# 1       1921      NaN            68.0     Comedy,Drama,Family   Comedy
# 2       1922      NaN            94.0          Fantasy,Horror  Fantasy
#
#    genre2   genre3                                   url  averageRating  \
# 0  Horror  Mystery  https://www.imdb.com/title/tt0010323            8.1
# 1   Drama   Family  https://www.imdb.com/title/tt0012349            8.3
# 2  Horror      NaN  https://www.imdb.com/title/tt0013442            7.9
#
#    numVotes  metascore  country primary_language            color    budget  \
# 0     57097        NaN  Germany              NaN  Black and White   $18,000
# 1    112377        NaN      USA              NaN  Black and White  $250,000
# 2     88440        NaN  Germany              NaN  Black and White       NaN
#
#   opening_weekend_usa gross_usa cumulative_worldwide  \
# 0                 NaN    $8,811               $8,811
# 1                 NaN       NaN              $26,916
# 2                 NaN       NaN              $19,054
#
#                                              tagline  \
# 0                          You must become Caligari.
# 1  This is the great film he has been working on ...
# 2  A thrilling mystery masterpiece - a chilling p...
#
#                                              summary  \
# 0  Hypnotist Dr. Caligari uses a somnambulist, Ce...
# 1  The Tramp cares for an abandoned child, but ev...
# 2  Vampire Count Orlok expresses interest in a ne...
#
#                                            image_url
# 0  https://m.media-amazon.com/images/M/MV5BNWJiNG...
# 1  https://m.media-amazon.com/images/M/MV5BZjhhMT...
# 2  https://m.media-amazon.com/images/M/MV5BMTAxYj...

# %% [markdown]
# ### Let's now add a column that takes the metascore and divides it by 10

# %%
df['new_metascore'] = df['metascore'] / 10.
df.head(3)
# Out:
#       tconst titleType                 primaryTitle  \
# 0  tt0010323     movie  The Cabinet of Dr. Caligari
# 1  tt0012349     movie                      The Kid
# 2  tt0013442     movie                    Nosferatu
#
#                            originalTitle  isAdult  start_year  endYear  \
# 0           Das Cabinet des Dr. Caligari        0        1920      NaN
# 1                                The Kid        0        1921      NaN
# 2  Nosferatu, eine Symphonie des Grauens        0        1922      NaN
#
#    runtimeMinutes                  genres   genre1  genre2   genre3  \
# 0            76.0  Fantasy,Horror,Mystery  Fantasy  Horror  Mystery
# 1            68.0     Comedy,Drama,Family   Comedy   Drama   Family
# 2            94.0          Fantasy,Horror  Fantasy  Horror      NaN
#
#                                     url  averageRating  numVotes  metascore  \
# 0  https://www.imdb.com/title/tt0010323            8.1     57097        NaN
# 1  https://www.imdb.com/title/tt0012349            8.3    112377        NaN
# 2  https://www.imdb.com/title/tt0013442            7.9     88440        NaN
#
#    country primary_language            color    budget opening_weekend_usa  \
# 0  Germany              NaN  Black and White   $18,000                 NaN
# 1      USA              NaN  Black and White  $250,000                 NaN
# 2  Germany              NaN  Black and White       NaN                 NaN
#
#   gross_usa cumulative_worldwide  \
# 0    $8,811               $8,811
# 1       NaN              $26,916
# 2       NaN              $19,054
#
#                                              tagline  \
# 0                          You must become Caligari.
# 1  This is the great film he has been working on ...
# 2  A thrilling mystery masterpiece - a chilling p...
#
#                                              summary  \
# 0  Hypnotist Dr. Caligari uses a somnambulist, Ce...
# 1  The Tramp cares for an abandoned child, but ev...
# 2  Vampire Count Orlok expresses interest in a ne...
#
#                                            image_url  new_metascore
# 0  https://m.media-amazon.com/images/M/MV5BNWJiNG...            NaN
# 1  https://m.media-amazon.com/images/M/MV5BZjhhMT...            NaN
# 2  https://m.media-amazon.com/images/M/MV5BMTAxYj...            NaN

# %% [markdown]
# ### If we want to rename a column, we can use `.rename()`

# %%
df.rename(columns={'startYear': 'start_year'}).head(3)
# Out:
#       tconst titleType                 primaryTitle  \
# 0  tt0010323     movie  The Cabinet of Dr. Caligari
# 1  tt0012349     movie                      The Kid
# 2  tt0013442     movie                    Nosferatu
#
#                            originalTitle  isAdult  start_year  endYear  \
# 0           Das Cabinet des Dr. Caligari        0        1920      NaN
# 1                                The Kid        0        1921      NaN
# 2  Nosferatu, eine Symphonie des Grauens        0        1922      NaN
#
#    runtimeMinutes                  genres   genre1  genre2   genre3  \
# 0            76.0  Fantasy,Horror,Mystery  Fantasy  Horror  Mystery
# 1            68.0     Comedy,Drama,Family   Comedy   Drama   Family
# 2            94.0          Fantasy,Horror  Fantasy  Horror      NaN
#
#                                     url  averageRating  numVotes  metascore  \
# 0  https://www.imdb.com/title/tt0010323            8.1     57097        NaN
# 1  https://www.imdb.com/title/tt0012349            8.3    112377        NaN
# 2  https://www.imdb.com/title/tt0013442            7.9     88440        NaN
#
#    country primary_language            color    budget opening_weekend_usa  \
# 0  Germany              NaN  Black and White   $18,000                 NaN
# 1      USA              NaN  Black and White  $250,000                 NaN
# 2  Germany              NaN  Black and White       NaN                 NaN
#
#   gross_usa cumulative_worldwide  \
# 0    $8,811               $8,811
# 1       NaN              $26,916
# 2       NaN              $19,054
#
#                                              tagline  \
# 0                          You must become Caligari.
# 1  This is the great film he has been working on ...
# 2  A thrilling mystery masterpiece - a chilling p...
#
#                                              summary  \
# 0  Hypnotist Dr. Caligari uses a somnambulist, Ce...
# 1  The Tramp cares for an abandoned child, but ev...
# 2  Vampire Count Orlok expresses interest in a ne...
#
#                                            image_url  new_metascore
# 0  https://m.media-amazon.com/images/M/MV5BNWJiNG...            NaN
# 1  https://m.media-amazon.com/images/M/MV5BZjhhMT...            NaN
# 2  https://m.media-amazon.com/images/M/MV5BMTAxYj...            NaN

# %% [markdown]
# ### But we haven't assigned it yet back to the df variable, it's still called startYear

# %%
df.head(3)
# Out:
#       tconst titleType                 primaryTitle  \
# 0  tt0010323     movie  The Cabinet of Dr. Caligari
# 1  tt0012349     movie                      The Kid
# 2  tt0013442     movie                    Nosferatu
#
#                            originalTitle  isAdult  start_year  endYear  \
# 0           Das Cabinet des Dr. Caligari        0        1920      NaN
# 1                                The Kid        0        1921      NaN
# 2  Nosferatu, eine Symphonie des Grauens        0        1922      NaN
#
#    runtimeMinutes                  genres   genre1  genre2   genre3  \
# 0            76.0  Fantasy,Horror,Mystery  Fantasy  Horror  Mystery
# 1            68.0     Comedy,Drama,Family   Comedy   Drama   Family
# 2            94.0          Fantasy,Horror  Fantasy  Horror      NaN
#
#                                     url  averageRating  numVotes  metascore  \
# 0  https://www.imdb.com/title/tt0010323            8.1     57097        NaN
# 1  https://www.imdb.com/title/tt0012349            8.3    112377        NaN
# 2  https://www.imdb.com/title/tt0013442            7.9     88440        NaN
#
#    country primary_language            color    budget opening_weekend_usa  \
# 0  Germany              NaN  Black and White   $18,000                 NaN
# 1      USA              NaN  Black and White  $250,000                 NaN
# 2  Germany              NaN  Black and White       NaN                 NaN
#
#   gross_usa cumulative_worldwide  \
# 0    $8,811               $8,811
# 1       NaN              $26,916
# 2       NaN              $19,054
#
#                                              tagline  \
# 0                          You must become Caligari.
# 1  This is the great film he has been working on ...
# 2  A thrilling mystery masterpiece - a chilling p...
#
#                                              summary  \
# 0  Hypnotist Dr. Caligari uses a somnambulist, Ce...
# 1  The Tramp cares for an abandoned child, but ev...
# 2  Vampire Count Orlok expresses interest in a ne...
#
#                                            image_url  new_metascore
# 0  https://m.media-amazon.com/images/M/MV5BNWJiNG...            NaN
# 1  https://m.media-amazon.com/images/M/MV5BZjhhMT...            NaN
# 2  https://m.media-amazon.com/images/M/MV5BMTAxYj...            NaN

# %% [markdown]
# ### So we have to write it back to the variable dataframe

# %%
df = df.rename(columns={'startYear': 'start_year'})
df.head(3)
# Out:
#       tconst titleType                 primaryTitle  \
# 0  tt0010323     movie  The Cabinet of Dr. Caligari
# 1  tt0012349     movie                      The Kid
# 2  tt0013442     movie                    Nosferatu
#
#                            originalTitle  isAdult  start_year  endYear  \
# 0           Das Cabinet des Dr. Caligari        0        1920      NaN
# 1                                The Kid        0        1921      NaN
# 2  Nosferatu, eine Symphonie des Grauens        0        1922      NaN
#
#    runtimeMinutes                  genres   genre1  genre2   genre3  \
# 0            76.0  Fantasy,Horror,Mystery  Fantasy  Horror  Mystery
# 1            68.0     Comedy,Drama,Family   Comedy   Drama   Family
# 2            94.0          Fantasy,Horror  Fantasy  Horror      NaN
#
#                                     url  averageRating  numVotes  metascore  \
# 0  https://www.imdb.com/title/tt0010323            8.1     57097        NaN
# 1  https://www.imdb.com/title/tt0012349            8.3    112377        NaN
# 2  https://www.imdb.com/title/tt0013442            7.9     88440        NaN
#
#    country primary_language            color    budget opening_weekend_usa  \
# 0  Germany              NaN  Black and White   $18,000                 NaN
# 1      USA              NaN  Black and White  $250,000                 NaN
# 2  Germany              NaN  Black and White       NaN                 NaN
#
#   gross_usa cumulative_worldwide  \
# 0    $8,811               $8,811
# 1       NaN              $26,916
# 2       NaN              $19,054
#
#                                              tagline  \
# 0                          You must become Caligari.
# 1  This is the great film he has been working on ...
# 2  A thrilling mystery masterpiece - a chilling p...
#
#                                              summary  \
# 0  Hypnotist Dr. Caligari uses a somnambulist, Ce...
# 1  The Tramp cares for an abandoned child, but ev...
# 2  Vampire Count Orlok expresses interest in a ne...
#
#                                            image_url  new_metascore
# 0  https://m.media-amazon.com/images/M/MV5BNWJiNG...            NaN
# 1  https://m.media-amazon.com/images/M/MV5BZjhhMT...            NaN
# 2  https://m.media-amazon.com/images/M/MV5BMTAxYj...            NaN

# %% [markdown]
# ### What shall we do with null values? We can use .fillna() to give them a specific value.

# %%
df['endYear'] = df['endYear'].fillna(-1)

# %% [markdown]
# ### Sorting your dataframe is also important. This can be done with `.sort_values()` Don't forget to inspect additional arguments of this function using `Shift + Tab` inside the function.

# %% [markdown]
# ### 1. Let's first sort the dataframe on `originalTitle` using argument `by`

# %%
df.sort_values(by='originalTitle')
# Out:
#          tconst titleType             primaryTitle  \
# 4928  tt2614684     movie                      '71
# 661   tt0090555     movie         Crocodile Dundee
# 715   tt0092493     movie      Crocodile Dundee II
# 3507  tt1022603     movie       500 Days of Summer
# 716   tt0092494     movie  *batteries not included
# ...         ...       ...                      ...
# 3342  tt0856288     movie                   Inside
# 2707  tt0402022     movie                 Æon Flux
# 5686  tt7134908  tvSeries                    Elite
# 1963  tt0235198     movie                 Audition
# 4677  tt2140203     movie            Wolf Children
#
#                     originalTitle  isAdult  start_year  endYear  \
# 4928                          '71        0        2014     -1.0
# 661            'Crocodile' Dundee        0        1986     -1.0
# 715         'Crocodile' Dundee II        0        1988     -1.0
# 3507         (500) Days of Summer        0        2009     -1.0
# 716       *batteries not included        0        1987     -1.0
# ...                           ...      ...         ...      ...
# 3342                À l'intérieur        0        2007     -1.0
# 2707                     Æon Flux        0        2005     -1.0
# 5686                        Élite        0        2018     -1.0
# 1963                      Ôdishon        0        1999     -1.0
# 4677  Ôkami kodomo no Ame to Yuki        0        2012     -1.0
#
#       runtimeMinutes                   genres     genre1     genre2    genre3  \
# 4928            99.0       Action,Crime,Drama     Action      Crime     Drama
# 661             97.0  Action,Adventure,Comedy     Action  Adventure    Comedy
# 715            108.0  Action,Adventure,Comedy     Action  Adventure    Comedy
# 3507            95.0     Comedy,Drama,Romance     Comedy      Drama   Romance
# 716            106.0    Comedy,Family,Fantasy     Comedy     Family   Fantasy
# ...              ...                      ...        ...        ...       ...
# 3342            82.0                   Horror     Horror        NaN       NaN
# 2707            93.0  Action,Adventure,Sci-Fi     Action  Adventure    Sci-Fi
# 5686            60.0     Crime,Drama,Thriller      Crime      Drama  Thriller
# 1963           115.0     Drama,Horror,Mystery      Drama     Horror   Mystery
# 4677           117.0  Animation,Drama,Fantasy  Animation      Drama   Fantasy
#
#                                        url  averageRating  numVotes  \
# 4928  https://www.imdb.com/title/tt2614684            7.2     50947
# 661   https://www.imdb.com/title/tt0090555            6.6     92299
# 715   https://www.imdb.com/title/tt0092493            5.7     53146
# 3507  https://www.imdb.com/title/tt1022603            7.7    470495
# 716   https://www.imdb.com/title/tt0092494            6.7     31354
# ...                                    ...            ...       ...
# 3342  https://www.imdb.com/title/tt0856288            6.8     37328
# 2707  https://www.imdb.com/title/tt0402022            5.5    123761
# 5686  https://www.imdb.com/title/tt7134908            7.6     46199
# 1963  https://www.imdb.com/title/tt0235198            7.2     72515
# 4677  https://www.imdb.com/title/tt2140203            8.1     38470
#
#       metascore    country primary_language  color        budget  \
# 4928       83.0         UK          English  Color           NaN
# 661        62.0  Australia          English  Color    $8,800,000
# 715        41.0  Australia          English  Color   $14,000,000
# 3507       76.0        USA          English  Color    $7,500,000
# 716        54.0        USA          English  Color   $25,000,000
# ...         ...        ...              ...    ...           ...
# 3342        NaN     France           French  Color  EUR2,400,000
# 2707       36.0        USA          English  Color   $62,000,000
# 5686        NaN      Spain          Spanish  Color           NaN
# 1963       69.0      Japan         Japanese  Color           NaN
# 4677       71.0      Japan         Japanese  Color           NaN
#
#      opening_weekend_usa     gross_usa cumulative_worldwide  \
# 4928            $55,761,    $1,270,847           $3,062,178
# 661          $8,038,855,  $174,803,506         $328,203,506
# 715         $24,462,976,  $109,306,210         $239,606,210
# 3507           $834,501,   $32,391,374          $60,722,734
# 716          $3,326,530,   $32,945,797          $65,088,797
# ...                  ...           ...                  ...
# 3342                 NaN           NaN             $792,184
# 2707        $12,661,112,   $25,874,337          $53,321,673
# 5686                 NaN           NaN                  NaN
# 1963                 NaN      $131,296             $359,853
# 4677                 NaN           NaN          $55,060,661
#
#                                                 tagline  \
# 4928                                                NaN
# 661               The Wizard of Auz hits The Big Apple!
# 715   The World's Favorite Adventurer Is Back For More!
# 3507                It was almost like falling in love.
# 716   Five ordinary people needed a miracle. Then on...
# ...                                                 ...
# 3342                              Terror Comes Calling.
# 2707                               Perfect Future Shock
# 5686                            "Til death do us part."
# 1963                             She always gets a part
# 4677                                        Love wildly
#
#                                                 summary  \
# 4928  In 1971, a young and disorientated British sol...
# 661   An American reporter goes to the Australian ou...
# 715   Australian outback expert protects his New Yor...
# 3507  An offbeat romantic comedy about a woman who d...
# 716   Aliens help a feisty old New York couple in th...
# ...                                                 ...
# 3342  Four months after the death of her husband, a ...
# 2707  Aeon Flux is a mysterious assassin working for...
# 5686  When three working-class teenagers begin atten...
# 1963  A widower takes an offer to screen girls at a ...
# 4677  After her werewolf lover unexpectedly dies in ...
#
#                                               image_url  new_metascore
# 4928  https://m.media-amazon.com/images/M/MV5BMTg1Nj...            8.3
# 661   https://m.media-amazon.com/images/M/MV5BZjNlMT...            6.2
# 715   https://m.media-amazon.com/images/M/MV5BMzkxYT...            4.1
# 3507  https://m.media-amazon.com/images/M/MV5BMTk5Mj...            7.6
# 716   https://m.media-amazon.com/images/M/MV5BM2JlMD...            5.4
# ...                                                 ...            ...
# 3342  https://m.media-amazon.com/images/M/MV5BNTgyOD...            NaN
# 2707  https://m.media-amazon.com/images/M/MV5BMTc2Mz...            3.6
# 5686  https://m.media-amazon.com/images/M/MV5BYWJhMW...            NaN
# 1963  https://m.media-amazon.com/images/M/MV5BOWYzZj...            6.9
# 4677  https://m.media-amazon.com/images/M/MV5BYzQxND...            7.1
#
# [5830 rows x 27 columns]

# %% [markdown]
# ### 2. Now sort the whole list on title in descending order, using `ascending=False`

# %%
df.sort_values(by='originalTitle', ascending=False)
# Out:
#          tconst titleType             primaryTitle  \
# 4677  tt2140203     movie            Wolf Children
# 1963  tt0235198     movie                 Audition
# 5686  tt7134908  tvSeries                    Elite
# 2707  tt0402022     movie                 Æon Flux
# 3342  tt0856288     movie                   Inside
# ...         ...       ...                      ...
# 716   tt0092494     movie  *batteries not included
# 3507  tt1022603     movie       500 Days of Summer
# 715   tt0092493     movie      Crocodile Dundee II
# 661   tt0090555     movie         Crocodile Dundee
# 4928  tt2614684     movie                      '71
#
#                     originalTitle  isAdult  start_year  endYear  \
# 4677  Ôkami kodomo no Ame to Yuki        0        2012     -1.0
# 1963                      Ôdishon        0        1999     -1.0
# 5686                        Élite        0        2018     -1.0
# 2707                     Æon Flux        0        2005     -1.0
# 3342                À l'intérieur        0        2007     -1.0
# ...                           ...      ...         ...      ...
# 716       *batteries not included        0        1987     -1.0
# 3507         (500) Days of Summer        0        2009     -1.0
# 715         'Crocodile' Dundee II        0        1988     -1.0
# 661            'Crocodile' Dundee        0        1986     -1.0
# 4928                          '71        0        2014     -1.0
#
#       runtimeMinutes                   genres     genre1     genre2    genre3  \
# 4677           117.0  Animation,Drama,Fantasy  Animation      Drama   Fantasy
# 1963           115.0     Drama,Horror,Mystery      Drama     Horror   Mystery
# 5686            60.0     Crime,Drama,Thriller      Crime      Drama  Thriller
# 2707            93.0  Action,Adventure,Sci-Fi     Action  Adventure    Sci-Fi
# 3342            82.0                   Horror     Horror        NaN       NaN
# ...              ...                      ...        ...        ...       ...
# 716            106.0    Comedy,Family,Fantasy     Comedy     Family   Fantasy
# 3507            95.0     Comedy,Drama,Romance     Comedy      Drama   Romance
# 715            108.0  Action,Adventure,Comedy     Action  Adventure    Comedy
# 661             97.0  Action,Adventure,Comedy     Action  Adventure    Comedy
# 4928            99.0       Action,Crime,Drama     Action      Crime     Drama
#
#                                        url  averageRating  numVotes  \
# 4677  https://www.imdb.com/title/tt2140203            8.1     38470
# 1963  https://www.imdb.com/title/tt0235198            7.2     72515
# 5686  https://www.imdb.com/title/tt7134908            7.6     46199
# 2707  https://www.imdb.com/title/tt0402022            5.5    123761
# 3342  https://www.imdb.com/title/tt0856288            6.8     37328
# ...                                    ...            ...       ...
# 716   https://www.imdb.com/title/tt0092494            6.7     31354
# 3507  https://www.imdb.com/title/tt1022603            7.7    470495
# 715   https://www.imdb.com/title/tt0092493            5.7     53146
# 661   https://www.imdb.com/title/tt0090555            6.6     92299
# 4928  https://www.imdb.com/title/tt2614684            7.2     50947
#
#       metascore    country primary_language  color        budget  \
# 4677       71.0      Japan         Japanese  Color           NaN
# 1963       69.0      Japan         Japanese  Color           NaN
# 5686        NaN      Spain          Spanish  Color           NaN
# 2707       36.0        USA          English  Color   $62,000,000
# 3342        NaN     France           French  Color  EUR2,400,000
# ...         ...        ...              ...    ...           ...
# 716        54.0        USA          English  Color   $25,000,000
# 3507       76.0        USA          English  Color    $7,500,000
# 715        41.0  Australia          English  Color   $14,000,000
# 661        62.0  Australia          English  Color    $8,800,000
# 4928       83.0         UK          English  Color           NaN
#
#      opening_weekend_usa     gross_usa cumulative_worldwide  \
# 4677                 NaN           NaN          $55,060,661
# 1963                 NaN      $131,296             $359,853
# 5686                 NaN           NaN                  NaN
# 2707        $12,661,112,   $25,874,337          $53,321,673
# 3342                 NaN           NaN             $792,184
# ...                  ...           ...                  ...
# 716          $3,326,530,   $32,945,797          $65,088,797
# 3507           $834,501,   $32,391,374          $60,722,734
# 715         $24,462,976,  $109,306,210         $239,606,210
# 661          $8,038,855,  $174,803,506         $328,203,506
# 4928            $55,761,    $1,270,847           $3,062,178
#
#                                                 tagline  \
# 4677                                        Love wildly
# 1963                             She always gets a part
# 5686                            "Til death do us part."
# 2707                               Perfect Future Shock
# 3342                              Terror Comes Calling.
# ...                                                 ...
# 716   Five ordinary people needed a miracle. Then on...
# 3507                It was almost like falling in love.
# 715   The World's Favorite Adventurer Is Back For More!
# 661               The Wizard of Auz hits The Big Apple!
# 4928                                                NaN
#
#                                                 summary  \
# 4677  After her werewolf lover unexpectedly dies in ...
# 1963  A widower takes an offer to screen girls at a ...
# 5686  When three working-class teenagers begin atten...
# 2707  Aeon Flux is a mysterious assassin working for...
# 3342  Four months after the death of her husband, a ...
# ...                                                 ...
# 716   Aliens help a feisty old New York couple in th...
# 3507  An offbeat romantic comedy about a woman who d...
# 715   Australian outback expert protects his New Yor...
# 661   An American reporter goes to the Australian ou...
# 4928  In 1971, a young and disorientated British sol...
#
#                                               image_url  new_metascore
# 4677  https://m.media-amazon.com/images/M/MV5BYzQxND...            7.1
# 1963  https://m.media-amazon.com/images/M/MV5BOWYzZj...            6.9
# 5686  https://m.media-amazon.com/images/M/MV5BYWJhMW...            NaN
# 2707  https://m.media-amazon.com/images/M/MV5BMTc2Mz...            3.6
# 3342  https://m.media-amazon.com/images/M/MV5BNTgyOD...            NaN
# ...                                                 ...            ...
# 716   https://m.media-amazon.com/images/M/MV5BM2JlMD...            5.4
# 3507  https://m.media-amazon.com/images/M/MV5BMTk5Mj...            7.6
# 715   https://m.media-amazon.com/images/M/MV5BMzkxYT...            4.1
# 661   https://m.media-amazon.com/images/M/MV5BZjNlMT...            6.2
# 4928  https://m.media-amazon.com/images/M/MV5BMTg1Nj...            8.3
#
# [5830 rows x 27 columns]

# %% [markdown]
# ### 3. Or we can sort on multiple columns. Now we need to use lists:

# %%
df.sort_values(by=['startYear', 'runtimeMinutes'], ascending=[False, True])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1446/3992083465.py in <cell line: 0>()
# ----> 1 df.sort_values(by=['startYear', 'runtimeMinutes'], ascending=[False, True])
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    7170             )
#    7171         if len(by) > 1:
# -> 7172             keys = [self._get_label_or_level_values(x, axis=axis) for x in by]
#    7173
#    7174             # need to rewrap columns in Series to apply key function
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1909             values = self.axes[axis].get_level_values(key)._values
#    1910         else:
# -> 1911             raise KeyError(key)
#    1912
#    1913         # Check for duplicates
#
# KeyError: 'startYear'
